# %% [markdown]
# <a href="https://colab.research.google.com/github/lakhan125/Statistics/blob/main/Normalize_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# let's import useful library

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
car = pd.read_csv('/content/data.csv')

# %%
car
# Out:
#           Make       Model  Year  ... city mpg  Popularity   MSRP
# 0          BMW  1 Series M  2011  ...       19        3916  46135
# 1          BMW    1 Series  2011  ...       19        3916  40650
# 2          BMW    1 Series  2011  ...       20        3916  36350
# 3          BMW    1 Series  2011  ...       18        3916  29450
# 4          BMW    1 Series  2011  ...       18        3916  34500
# ...        ...         ...   ...  ...      ...         ...    ...
# 11909    Acura         ZDX  2012  ...       16         204  46120
# 11910    Acura         ZDX  2012  ...       16         204  56670
# 11911    Acura         ZDX  2012  ...       16         204  50620
# 11912    Acura         ZDX  2013  ...       16         204  50920
# 11913  Lincoln      Zephyr  2006  ...       17          61  28995
#
# [11914 rows x 16 columns]

# %%
car.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
car.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
pip install plotly --quiet

# %%
sns.set(rc= {"figure.figsize": (12, 8)})

# %%
import plotly.express as px

# %% [markdown]
# ### See distribution of Numeric columns
# - if numeric feature not normal dustributed then apply normalization

# %%
# seperate numeric columns for object
numeric_feature = car.select_dtypes('int64')
numeric_feature
# Out:
#        Year  highway MPG  city mpg  Popularity   MSRP
# 0      2011           26        19        3916  46135
# 1      2011           28        19        3916  40650
# 2      2011           28        20        3916  36350
# 3      2011           28        18        3916  29450
# 4      2011           28        18        3916  34500
# ...     ...          ...       ...         ...    ...
# 11909  2012           23        16         204  46120
# 11910  2012           23        16         204  56670
# 11911  2012           23        16         204  50620
# 11912  2013           23        16         204  50920
# 11913  2006           26        17          61  28995
#
# [11914 rows x 5 columns]

# %% [markdown]
# - It's numeric features so let's see descriptive statistics

# %%
numeric_feature.describe()
# Out:
#                Year   highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean    2010.384338     26.637485     19.733255   1554.911197  4.059474e+04
# std        7.579740      8.863001      8.987798   1441.855347  6.010910e+04
# min     1990.000000     12.000000      7.000000      2.000000  2.000000e+03
# 25%     2007.000000     22.000000     16.000000    549.000000  2.100000e+04
# 50%     2015.000000     26.000000     18.000000   1385.000000  2.999500e+04
# 75%     2016.000000     30.000000     22.000000   2009.000000  4.223125e+04
# max     2017.000000    354.000000    137.000000   5657.000000  2.065902e+06

# %% [markdown]
# - Let's analysis MSRP - : manufacturer’s suggested retail price
#
# see BOX plot for see how much spread data of MSRP

# %%
px.box(numeric_feature, y = numeric_feature['MSRP'], title = 'Spred of Data MSRP')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0d0e1e9a-72e5-4672-80d3-2c0079faa495" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0d0e1e9a-72e5-4672-80d3-2c0079faa495")) {
#                     Plotly.newPlot(
#                         '0d0e1e9a-72e5-4672-80d3-2c0079faa495',
# ...

# %%
px.box(numeric_feature, y = numeric_feature['Popularity'], title = 'popularity of car')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="af81f0b4-dac9-4ca8-85c5-a66f4d9770cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("af81f0b4-dac9-4ca8-85c5-a66f4d9770cb")) {
#                     Plotly.newPlot(
#                         'af81f0b4-dac9-4ca8-85c5-a66f4d9770cb',
# ...

# %%
px.strip(numeric_feature,  y='MSRP')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="59cf7a18-1c3b-454d-ac56-b356bd8c64a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("59cf7a18-1c3b-454d-ac56-b356bd8c64a5")) {
#                     Plotly.newPlot(
#                         '59cf7a18-1c3b-454d-ac56-b356bd8c64a5',
# ...

# %%
px.strip(numeric_feature,  y='highway MPG')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e8a78e97-9371-44c4-8d46-59939f6d0117" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e8a78e97-9371-44c4-8d46-59939f6d0117")) {
#                     Plotly.newPlot(
#                         'e8a78e97-9371-44c4-8d46-59939f6d0117',
# ...

# %% [markdown]
# - it show most of the highway mpg range is 12 - 50 like 70% or above
#
# - So one good measure of spread is IQR = Q3 - Q1 see how much value in this range. and this is robust for outliers
#
# - if you see box plot, it show q3 - q1 is range 22 - 30
# it means 50% of data in this range
#
# - and strip graph show above 50 it seems like 20% to 25% of data in range of 50 - 120.
#
# so this is outlier part of our feature
#
# - OR you see in boxplot. how much data in lower or  upper boundries

# %%
px.box(numeric_feature, y='highway MPG')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e85fa9a0-333a-4e17-8bad-d02a8952fbd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e85fa9a0-333a-4e17-8bad-d02a8952fbd5")) {
#                     Plotly.newPlot(
#                         'e85fa9a0-333a-4e17-8bad-d02a8952fbd5',
# ...

# %% [markdown]
# - Now let's normalize MSRP data

# %%
numeric_feature.dtypes
# Out:
# Year           int64
# highway MPG    int64
# city mpg       int64
# Popularity     int64
# MSRP           int64
# dtype: object

# %%
import plotly.figure_factory as ff
import plotly.graph_objects as go
